# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
datalatih = pd.read_excel("data testing.xlsx")
datalatih.head(25)
# Out:
#       NAMA  Umur Kelamin     Gaji  Tahun Mulai Bekerja  Jumlah Anak
# 0     Reza    22       L  2400000                 2021            1
# 1    Vicky    24       L  3000000                 2023            2
# 2     Abid    22       L  3000000                 2021            1
# 3    Rafly    21       L  5000000                 2021            1
# 4    Iqbal    24       L  2400000                 2021            1
# 5    Hafid    20       L  5000000                 2021            2
# 6    Putri    20       P  5000000                 2023            1
# 7     Koko    28       L  3000000                 2023            1
# 8     Jaya    22       L  2400000                 2021            1
# 9    Bella    23       P  5000000                 2021            2
# 10   Salsa    20       P  3000000                 2020            1
# 11   Cicil    25       P  3000000                 2023            4
# 12   Yolam    27       L  2400000                 2020            3
# 13    Elga    27       L  3000000                 2023            2
# 14     tri    28       P  3000000                 2021            2
# 15    neza    23       P  2400000                 2021            2
# 16   fajar    21       L  3000000                 2021            2
# 17  naufal    21       L  2400000                 2020            4
# 18     aji    21       L  5000000                 2020            4
# 19  lathif    22       L  6700000                 2021            1
# 20    yoga    24       L  3000000                 2021            1
# 21    beni    29       P  6700000                 2021            2
# 22    adam    29       L  3000000                 2021            1
# 23   Bagas    27       L  2400000                 2020            4

# %%
datalatih.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NAMA                 24 non-null     object
#  1   Umur                 24 non-null     int64
#  2   Kelamin              24 non-null     object
#  3   Gaji                 24 non-null     int64
#  4   Tahun Mulai Bekerja  24 non-null     int64
#  5   Jumlah Anak          24 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 1.2+ KB

# %%
from sklearn.cluster import KMeans
plt.scatter(datalatih.Gaji, datalatih.Umur, s = 50, c = "c", marker = "o", alpha = 0.5)
plt.show()

# %%
x = datalatih.drop(["NAMA","Kelamin"], axis=1)
x.head(25)
# Out:
#     Umur     Gaji  Tahun Mulai Bekerja  Jumlah Anak
# 0     22  2400000                 2021            1
# 1     24  3000000                 2023            2
# 2     22  3000000                 2021            1
# 3     21  5000000                 2021            1
# 4     24  2400000                 2021            1
# 5     20  5000000                 2021            2
# 6     20  5000000                 2023            1
# 7     28  3000000                 2023            1
# 8     22  2400000                 2021            1
# 9     23  5000000                 2021            2
# 10    20  3000000                 2020            1
# 11    25  3000000                 2023            4
# 12    27  2400000                 2020            3
# 13    27  3000000                 2023            2
# 14    28  3000000                 2021            2
# 15    23  2400000                 2021            2
# 16    21  3000000                 2021            2
# 17    21  2400000                 2020            4
# 18    21  5000000                 2020            4
# 19    22  6700000                 2021            1
# 20    24  3000000                 2021            1
# 21    29  6700000                 2021            2
# 22    29  3000000                 2021            1
# 23    27  2400000                 2020            4

# %%
y = datalatih["NAMA"]
y.head(25)
# Out:
# 0       Reza
# 1      Vicky
# 2       Abid
# 3      Rafly
# 4      Iqbal
# 5      Hafid
# 6      Putri
# 7       Koko
# 8       Jaya
# 9      Bella
# 10     Salsa
# 11     Cicil
# 12     Yolam
# 13      Elga
# 14       tri
# 15      neza
# 16     fajar
# 17    naufal
# 18       aji
# 19    lathif
# 20      yoga
# 21      beni
# 22      adam
# 23     Bagas
# Name: NAMA, dtype: object

# %%
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import GaussianNB

modelnb = GaussianNB()

nbtrain = modelnb.fit(x, y)
datauji = pd.read_excel("data testing.xlsx")
datauji.head(25)
# Out:
#       NAMA  Umur Kelamin     Gaji  Tahun Mulai Bekerja  Jumlah Anak
# 0     Reza    22       L  2400000                 2021            1
# 1    Vicky    24       L  3000000                 2023            2
# 2     Abid    22       L  3000000                 2021            1
# 3    Rafly    21       L  5000000                 2021            1
# 4    Iqbal    24       L  2400000                 2021            1
# 5    Hafid    20       L  5000000                 2021            2
# 6    Putri    20       P  5000000                 2023            1
# 7     Koko    28       L  3000000                 2023            1
# 8     Jaya    22       L  2400000                 2021            1
# 9    Bella    23       P  5000000                 2021            2
# 10   Salsa    20       P  3000000                 2020            1
# 11   Cicil    25       P  3000000                 2023            4
# 12   Yolam    27       L  2400000                 2020            3
# 13    Elga    27       L  3000000                 2023            2
# 14     tri    28       P  3000000                 2021            2
# 15    neza    23       P  2400000                 2021            2
# 16   fajar    21       L  3000000                 2021            2
# 17  naufal    21       L  2400000                 2020            4
# 18     aji    21       L  5000000                 2020            4
# 19  lathif    22       L  6700000                 2021            1
# 20    yoga    24       L  3000000                 2021            1
# 21    beni    29       P  6700000                 2021            2
# 22    adam    29       L  3000000                 2021            1
# 23   Bagas    27       L  2400000                 2020            4

# %%
x_test = datauji.drop(["NAMA","Kelamin"], axis=1)
x_test.head(25)
# Out:
#     Umur     Gaji  Tahun Mulai Bekerja  Jumlah Anak
# 0     22  2400000                 2021            1
# 1     24  3000000                 2023            2
# 2     22  3000000                 2021            1
# 3     21  5000000                 2021            1
# 4     24  2400000                 2021            1
# 5     20  5000000                 2021            2
# 6     20  5000000                 2023            1
# 7     28  3000000                 2023            1
# 8     22  2400000                 2021            1
# 9     23  5000000                 2021            2
# 10    20  3000000                 2020            1
# 11    25  3000000                 2023            4
# 12    27  2400000                 2020            3
# 13    27  3000000                 2023            2
# 14    28  3000000                 2021            2
# 15    23  2400000                 2021            2
# 16    21  3000000                 2021            2
# 17    21  2400000                 2020            4
# 18    21  5000000                 2020            4
# 19    22  6700000                 2021            1
# 20    24  3000000                 2021            1
# 21    29  6700000                 2021            2
# 22    29  3000000                 2021            1
# 23    27  2400000                 2020            4

# %%
y_uji = datauji["NAMA"]
y_uji.head(25)
# Out:
# 0       Reza
# 1      Vicky
# 2       Abid
# 3      Rafly
# 4      Iqbal
# 5      Hafid
# 6      Putri
# 7       Koko
# 8       Jaya
# 9      Bella
# 10     Salsa
# 11     Cicil
# 12     Yolam
# 13      Elga
# 14       tri
# 15      neza
# 16     fajar
# 17    naufal
# 18       aji
# 19    lathif
# 20      yoga
# 21      beni
# 22      adam
# 23     Bagas
# Name: NAMA, dtype: object

# %%
Y_predict = nbtrain.predict(x_test)
print("Prediksi Naive Bayes : ",Y_predict)
# Out:
# Prediksi Naive Bayes :  ['Jaya' 'Vicky' 'Abid' 'Rafly' 'Iqbal' 'Hafid' 'Putri' 'Koko' 'Jaya'
#  'Bella' 'Salsa' 'Cicil' 'Yolam' 'Elga' 'tri' 'neza' 'fajar' 'naufal'
#  'aji' 'lathif' 'yoga' 'beni' 'adam' 'Bagas']

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(y_uji, Y_predict)
print("Akurasi Naive Bayes : ",accuracy)
# Out:
# Akurasi Naive Bayes :  0.9583333333333334

# %%
from sklearn.metrics import classification_report
print(classification_report(y_uji, Y_predict))
# Out:
#               precision    recall  f1-score   support
#
#         Abid       1.00      1.00      1.00         1
#        Bagas       1.00      1.00      1.00         1
#        Bella       1.00      1.00      1.00         1
#        Cicil       1.00      1.00      1.00         1
#         Elga       1.00      1.00      1.00         1
#        Hafid       1.00      1.00      1.00         1
#        Iqbal       1.00      1.00      1.00         1
#         Jaya       0.50      1.00      0.67         1
#         Koko       1.00      1.00      1.00         1
#        Putri       1.00      1.00      1.00         1
#        Rafly       1.00      1.00      1.00         1
#         Reza       0.00      0.00      0.00         1
#        Salsa       1.00      1.00      1.00         1
#        Vicky       1.00      1.00      1.00         1
#        Yolam       1.00      1.00      1.00         1
#         adam       1.00      1.00      1.00         1
#          aji       1.00      1.00      1.00         1
#         beni       1.00      1.00      1.00         1
#        fajar       1.00      1.00      1.00         1
#       lathif       1.00      1.00      1.00         1
#       naufal       1.00      1.00      1.00         1
#         neza       1.00      1.00      1.00         1
#          tri       1.00      1.00      1.00         1
#         yoga       1.00      1.00      1.00         1
#
#     accuracy                           0.96        24
#    macro avg       0.94      0.96      0.94        24
# weighted avg       0.94      0.96      0.94        24
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
